# %% [markdown]
# <a href="https://colab.research.google.com/github/tsvoronos/API202-students/blob/main/hw/API203/api203_hw2_questions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # API-203M A PROBLEM SET #2
#
# ---
#
#
# **Due on Wednesday, March 22, at 11:59 p.m.**

# %% [markdown]
# **I - INSTRUCTIONS**
# To successfully complete this problem set, please follow these steps:
#
# 1. **Create a copy of this Jupyter notebook in your own drive by clicking `Copy to Drive` in the menubar (this is explained below in more detail below) - *if you do not do this your work will not be saved!***
#     1. Remember to save your work frequently by pressing `command-S` or clicking `File > Save` in the menubar.
#     1. We recommend completing this problem set in Google Chrome.
# 2. **Insert all your answers into your copy of the document.**
#     1. Please include every portion of your submission in this document unless a separate electronic file is explicitly requested.
#     3. All numerical calculations should be done in the notebook itself, using R code. If you have to do calculations by hand, include a picture of your handwritten work.
#     2. To add an image of handwritten work, screenshots, or anything else, add a new text cell and click the small image icon in the menubar above the cell. After inserting an image, press the `esc` key to show the image. If you have trouble with this method, upload your image to [Freeimage.host](https://freeimage.host), copy a Markdown link, and paste it in a text cell.
# 3. **Once your document is complete, please save and submit the notebook on Canvas as a PDF.**
#     1. Click `View > Expand sections` in the menubar to make sure all work is visible (if it is greyed out then it is already visible).
#     1. Click `Runtime > Run all` in the menubar to make sure all of your code is executed.
#     1. Click `File > Print` in the menubar and choose the `Save as PDF` option in Chrome to export your notebook as a PDF.
#     1. Check to make sure answers do not get cut off - when you go to print the PDF we recommend clicking on `More settings` and setting `Margins` to `None`.
#     1. Alternatively, use [this Google Chrome extension](https://chrome.google.com/webstore/detail/gofullpage-full-page-scre/fdpohaocaechififmbbbbbknoalclacl) to create a single PDF without having to worry about margins.
#     1. Submit your file on Canvas.

# %% [markdown]
# **II - IDENTIFICATION**
# 1. **Your Full Name:** `     `
#
# 2. **Group Members (classmates with whom you worked on this problem set):**
#     1. `     `
#     2. `     `
#     3. `     `
#     4. `     `
#
# 3. **Compliance with HKS Academic Code**
# We abide by the Harvard Kennedy School Academic code for all aspects of the course. In terms of problem sets, unless explicitly written otherwise, the norms are the following: You are free (and encouraged) to discuss problem sets with your classmates. However, you must hand in your own unique written work and code in all cases. Any copy/paste of another’s work is plagiarism. In other words, you may work with your classmate(s), sitting side-by-side (physically or remotely!) and going through the problem set question by question, but you must each type your own answers and your own code. For more details, please see syllabus.
#
#     **I certify that my work in this problem set complies with the HKS Academic Code**
#     - [ ] Yes
#     - [ ] No
#
# ---

# %% [markdown]
# # PART 1: IV Application - Maternal and Children’s Educational Outcomes
#
# For this problem set, we will be examining the mechanism and methods used in Andrabi, Das, and Khwaja. (2012). What Did You Do All Day? Maternal Education and Child Outcomes. Journal of Human Resources, 47, pp. 873-912. [Link to paper](https://khwaja.scholar.harvard.edu/files/asimkhwaja/files/what_did_you_do_all_day.pdf)
#
# * Abstract and introduction: 873-877
# * Econometric Specification and Identification strategy: 886-890
# * Results: Table 4, end of pg. 892-893 (stop at "The final panel")

# %% [markdown]
# **1. Read the paper. What is the primary research question that the authors are trying to answer? What are the challenges to answering this question?**

# %% [markdown]
# Your answer:

# %% [markdown]
# **2. The authors used an instrumental variable approach because they believed a simple OLS specification would be insufficient. What are two possible confounders (omitted variables) that would bias the results from a simple OLS specification? Explain the mechanism of the omitted variable and whether it would lead to an understatement or overstatement of the true effect.**

# %% [markdown]
# Your answer:

# %% [markdown]
# **3. What is/are the instrument(s) used by the authors in this study?**

# %% [markdown]
# Your answer here:

# %% [markdown]
# **4. To identify the causal impact, the authors employ an instrumental variable methodology. Generally, what characteristics must an instrument have for it to be considered valid? Explain these characteristics in specific terms of the instrument(s) used in the paper.**

# %% [markdown]
# Your answer:

# %% [markdown]
# **5. Do you believe that the instrument(s) is/are truly exogenous? Why or why not? If so, provide support for this assumption. If not, provide an alternate mechanism for how the instrument(s) may affect the outcome.**

# %% [markdown]
# Your answer here:

# %% [markdown]
# ## Instrument Relevance

# %% [markdown]
# **6. To assess whether the instrument is relevant, we can examine the output from the first stage regression, presented in table 3 of the paper (and copied below). Looking at model (1), interpret the coefficient on “Girls School Present by Age 7”. What does it suggest about the strength of the first-stage relationship? (Note: You could also check the F-statistics, but it is not essential. A rule of thumb for statistical significance for instruments is an F-statistic greater than 11.)**

# %% [markdown]
# ![table3.png](data:image/png;base64,...)

# %% [markdown]
# Your answer here:

# %% [markdown]
# ## The Local Average Treatment Effect

# %% [markdown]
# **7. In this study, what is the population for which this local average treatment effect is identified (i.e. who are the compliers)?**

# %% [markdown]
# Your answer here:

# %% [markdown]
# **8. Explain the problems involved with generalizing the results of this study as a result of using an instrumental variable approach.**

# %% [markdown]
# Your answer here:

# %% [markdown]
# **9. Despite these problems, discuss the extent to which you believe these results to be generalizable. In what contexts, and to what populations, would these findings be applicable? Are these contexts/populations important, or is the generalizability of the paper too narrow to be useful?**

# %% [markdown]
# Your answer here:

# %% [markdown]
# # PART II: Replicating IV Estimates [OPTIONAL]

# %% [markdown]
# In this optional section, **you will replicate the results of the IV regressions from the paper.** We are grateful to Professor Khwaja sharing the data with us. We will be using the dataset motherchild.dta.
#
# This dataset contains data from 4,331 children in rural Pakistan and includes relevant information about each child’s mother. Definitions of variables on the file are presented here.
#
# * `childgender`: Gender of the child (1=Male; 2=Female)
# * `childage`: Child age
# * `enrolled`: Child enrolled in school (0=Not enrolled ;1=Enrolled)
# * `momage`: Mother’s age
# * `mauza`: Current mauza / sub-district code
# * `momeduc`: Whether or not mother has some education (0=No education; 1=Some education)
# * `schoolpresent7`: Was a girls school present in birth village by age 7 (0=No; 1=Yes)
# * `birth_tehsil`: Tehsil (district) of birth
# * `child_edu_time`: Number of minutes spent on educational activities outside of school

# %%
library(tidyverse)

check_installed <- require(fixest)
if(check_installed==F){
  install.packages("fixest")
  require(fixest)
}

motherchild <- read_csv("https://raw.githubusercontent.com/tsvoronos/API202-students/main/data/motherchild.csv")
# Out:
# Warning message in system("timedatectl", intern = TRUE):
# “running command 'timedatectl' had status 1”
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.1 ──
#
# ✔ ggplot2 3.4.1     ✔ purrr   1.0.1
# ✔ tibble  3.1.8     ✔ dplyr   1.1.0
# ✔ tidyr   1.3.0     ✔ stringr 1.4.1
# ✔ readr   2.1.4     ✔ forcats 1.0.0
#
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
#
# Loading required package: fixest
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘fixest’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘zoo’, ‘Formula’, ‘numDeriv’, ‘sandwich’, ‘Rcpp’, ‘dreamerr’

# %% [markdown]
# **1. First, let us run an OLS regression of child’s time spent on educational activities on mother’s education, controlling for the age and gender of the child, age of the mother (treating both mother’s and child’s age as categorical, including one dummy variable for each category), and including fixed effects for birth tehsil (district). Cluster your standard errors on current mauza (sub-district) (NOTE: this is different from what is used in the paper, but close enough). Report the coefficient on mother’s education and its standard error. Were you able to replicate the OLS estimate from column 1 of table 4A? Interpret this coefficient.**
#
# HINT1: instead of using the command lm, you can try to use the command feols to include fixed effects. This command is part of the fixest library that we installed at the beginning of this part. The syntax for this comomand is:
# feols(y ~ x1 + x2 | fe1, data = data)), where fe1 is the name of the fixed effect variable (birth_tehsil in this example).
#
# HINT2: if you use the feols, you can include one dummy variable for each category using the following syntax: i(x2). For example, if x2 is categorical you can include:
# feols(y ~ x1 + i(x2) | fe1, data = data))

# %%
# Your code here:

# %% [markdown]
# Your answer:

# %% [markdown]
# **2. Next, we will run the Instrumental Variables specification.**
#
# **A. First, run the first-stage regression of mother’s education on whether a girls’ school present by age 7, controlling for mother’s and child’s age, child’s gender, and mother’s birth tehsil fixed effects (same as before). Cluster at the mauza level as before.**

# %%
# Your code here:

# %% [markdown]
# **B.From the model, create predicted values of mother’s education.**
#
# HINT: to save the fitted values of the first stage you can use the following syntax:
#
# ``
# data$new_variable_name <- first_stage$fitted.values
# ``
#
# where `` first_stage`` is the name of the first stage regression output.

# %%
# Your code here:

# %% [markdown]
# **C. Now regress child’s time spent on educational activities on this prediction of mother’s education, controlling for mother’s and child’s age, child’s gender, and mother’s birth tehsil. Report the coefficient on predicted mother’s education (ignore the standard error). Were you able to replicate the IV estimate from table 4A? Interpret this coefficient.**

# %%
# Your code here:

# %% [markdown]
# Your answer here:

# %% [markdown]
# **3. Lastly, let us re-run the IV regression with the R command feols (check the appendix of Handout 3). Report your coefficient on mother’s education and its standard error. Was this point estimate the same as what you got in the previous question?**

# %%
# Your code here:

# %% [markdown]
# Your answer here:
