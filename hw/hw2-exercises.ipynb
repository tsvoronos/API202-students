# %% [markdown]
# <a href="https://colab.research.google.com/github/tsvoronos/API202-staff/blob/main/hw/hw2/hw2-exercises.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # API-202M ABC PROBLEM SET #2
# **Due on Wednesday, February 8, at 11:59 p.m.**

# %% [markdown]
# **I - INSTRUCTIONS**
# To successfully complete this problem set, please follow these steps:
#
# 1. **Create a copy of this Jupyter notebook in your own drive by clicking `Copy to Drive` in the menubar (this is explained below in more detail below) - *if you do not do this your work will not be saved!***
#     1. Remember to save your work frequently by pressing `command-S` or clicking `File > Save` in the menubar.
#     1. We recommend completing this problem set in Google Chrome.
# 2. **Insert all your answers into your copy of the document.**
#     1. Please include every portion of your submission in this document unless a separate electronic file is explicitly requested.
#     3. All numerical calculations should be done in the notebook itself, using R code. If you have to do calculations by hand, include a picture of your handwritten work.
#     2. To add an image of handwritten work, screenshots, or anything else, add a new text cell and click the small image icon in the menubar above the cell. After inserting an image, press the `esc` key to show the image. If you have trouble with this method, upload your image to [Freeimage.host](https://freeimage.host), copy a Markdown link, and paste it in a text cell.
# 3. **Once your document is complete, please save and submit the notebook on Canvas as a PDF.**
#     1. Click `View > Expand sections` in the menubar to make sure all work is visible (if it is greyed out then it is already visible).
#     1. Click `Runtime > Run all` in the menubar to make sure all of your code is executed.
#     1. Click `File > Print` in the menubar and choose the `Save as PDF` option in Chrome to export your notebook as a PDF.
#     1. Check to make sure answers do not get cut off - when you go to print the PDF we recommend clicking on `More settings` and setting `Margins` to `None`.
#     1. Submit your file on Canvas.

# %% [markdown]
# **II - IDENTIFICATION**
# 1. **Your Full Name:** `     `
#
# 2. **Group Members (classmates with whom you worked on this problem set):**
#     1. `     `
#     2. `     `
#     3. `     `
#     4. `     `
#
# 3. **Compliance with HKS Academic Code**
# We abide by the Harvard Kennedy School Academic code for all aspects of the course. In terms of problem sets, unless explicitly written otherwise, the norms are the following: You are free (and encouraged) to discuss problem sets with your classmates. However, you must hand in your own unique written work and code in all cases. Any copy/paste of another’s work is plagiarism. In other words, you may work with your classmate(s), sitting side-by-side (physically or remotely!) and going through the problem set question by question, but you must each type your own answers and your own code. For more details, please see syllabus.
#
#     **I certify that my work in this problem set complies with the HKS Academic Code**
#     - [ ] Yes
#     - [ ] No
#
# ---

# %% [markdown]
# ## Load `R` libraries and data
#
# **Please refer this [R Cheat Sheet](https://bit.ly/HKS-R) which includes the commands you learned last semester in addition to a number of additional ones.**
#
# The code cell below imports the R tidyverse. Make sure to run it before starting the problem set!
#
# *Note: Click the "play" button that appears when you hover over a cell to run it. The first time you do this you may receive an alert that this notebook was not authored by Google. If so, click "Run anyway" to proceed.*

# %%
library(tidyverse)
datawage <- read.csv("https://github.com/tsvoronos/API202-students/blob/f3f34cd64a4f98b4fe6507805e9579f5323f1b9a/data/gap2023.csv?raw=1")

# %% [markdown]
# # PART I: HOURLY WAGES, YEARS OF EDUCATION AND TEST SCORES
#
# The purpose of this exercise is to help you understand multiple regression and omitted variable bias.
#
# The dataset for this question is an extract of data on the earnings and demographics of a subset of adults working in the USA. The variables in this dataset are:
#
# *   `salary`: yearly salary
# *   `age`: age in years
# *   `hours`: usual weekly hours worked
# *   `weeks`: weeks worked last year
# *   `educ`: years of education
# *   `test_score`: test score of individuals in grade 10
# *   `immigrant`: immigrant identification, denoted as 1 if the individual is an immigrant and 0 otherwise. An immigrant is anyone living in the U.S. who is not a U.S. citizen.

# %% [markdown]
# **1. Let's start with plotting the variable years of education. Use a histogram to find the mode of years of education (you can assess this visually). The mode is the most frequent number, that is, the number that occurs the highest number of times in the dataset.**
#
# **HINT: the code for a histogram
# is `ggplot(dataset, aes(x = var)) + geom_histogram()`
# Where dataset is the name of the dataset and var is the variable of interest.**

# %%
# Your code here

# %% [markdown]
# Your answer here

# %% [markdown]
# **2.What is the median of the hours variable and the mean yearly salary?**
#
# HINT: you can use the summary command (e.g., summary(data$var) to get summary statistics for a variable called var in a dataset called data). Or, using the tidyverse, you can use the `select(var1,var2)` command and pipe that into `summary()`.

# %%
# Your code here

# %% [markdown]
# Your answer here

# %% [markdown]
# **3. Using a regression, test the null hypothesis that the average hourly wage is the same for immigrants and non-immigrants. Also interpret the constant of the regression that you run and discuss whether it is meaningful.**
#
# HINT: First, you will need to create a new variable with the hourly wage in the dataset (in this case, gap). The variable is produced using a formula that uses the variables: `salary`, `weeks`, and `hours`). The code to create a new variable in the dataset is: `dataset <- mutate(dataset, newvar = formula)`.

# %%
# Your code here

# %% [markdown]
# Your answer here

# %% [markdown]
# **4. True, False, or Uncertain?  “Based on your results from the prior question, would it be correct to say that there is less than a 5% chance that the average wages of immigrants and non-immigrants are the same in the population? Include a brief explanation.”  Explain your answer.**

# %% [markdown]
# Check one:
# - [ ] True
# - [ ] False
# - [ ] Uncertain
#
# Your explanation here!

# %% [markdown]
# **5. Run now a regression of the `immigrant` and `educ` variables on the hourly wage. Interpret each coefficient of the regression.**

# %%
# Your code here

# %% [markdown]
# Your answer here

# %% [markdown]
# **6. Predict the hourly income for two people, a US citizen high school dropout with 9 years of schooling and an immigrant with 15 years of schooling.**

# %% [markdown]
# Your answer here

# %%
#Your Answer Here

# %% [markdown]
# **7. Now, let's include the test scores among the independent variables in the regression described in Question 5. Why do you think the slope coefficient on years of education changes as it does between the two regressions? Provide an explanation to a policy maker interested in your results.**

# %%
# Your code here

# %% [markdown]
# Your answer here

# %% [markdown]
# **8. If we fail to include the test score in the regression, then the coefficient of the years of education is an ________________ of the true relationship between years of education and hourly wage.**

# %% [markdown]
# Check one:
# - [ ] Overstatement
# - [ ] Understatement
#
# Your explanation here

# %% [markdown]
# **9. Now think about  the marriage status of the individual. Unfortunately, we do not have this information in the dataset. Discuss whether omitting the marriage status from a regression of years of education, immigrant, age, test score on hourly wage may generate a substantial omitted variable bias in the estimate of the impact of years of education on hourly wage. Clearly write the short and long regressions and discuss the sign of the omitted variable bias.**
#
# Note: To write out the equation you can type using words (e.g., Beta_1 or Beta_1_Hat), or you could write the equation by hand and insert an image of it.

# %% [markdown]
# Your explanation here

# %% [markdown]
# **10. The outputs from the regressions are usually presented as well-formatted tables. In this question, you will learn how to nicely format a table with the results from multiple regressions.**
#
# **First, run the script below installing the package modelsummary (this may take a minute or so to install).**

# %%
check_installed <- require(modelsummary)
if(check_installed==F){
  install.packages("modelsummary")
  require(modelsummary)
}

# %% [markdown]
# **Next, include the results of the regressions you run in this exercise in a nicely formatted table using the existing code below to get started**
#
# In the code snippet below, `fit1`, `fit2`, and `fit3` is the regression outputs you saved in Questions 3, 5 and 7, `Name of Outcome Variable` is what you would like to show up on the top of each column, and `var1` and `var2` are the name of two independent variables included in the regression (e.g., educ). Note that you can and should include all the variables that you used in the models you ran in the `coef_map` line.
# ```
#   modelsummary(list("Name Outcome Variable" = fit1,"Name Outcome Variable" = fit2, "Name Outcome Variable" = fit3),
#   stars=T,
#   coef_map = c("(Intercept)" = "Constant","var1" = "Name of var1", "var2" = "Name of var2"),
#  title = "Add Here the Title of the Table",
#   gof_omit = 'IC|Log',
#   output="jupyter")
#
#   ```

# %%
# Your answer here

# %% [markdown]
# **11. Now compare the R-squared in the different columns of the Table you created in the previous Question. What do you observe? Is it consistent with your prior? Discuss also whether your observation on the value of the $R^2$ increases the internal validity of the regression in the last column (result of Question 7) compared to the previous column (result of Question 5).**

# %% [markdown]
# Your explanation here

# %% [markdown]
# # PART II: OVB IN THE NEWS

# %% [markdown]
# **A blog post on the New York Times discusses the health benefits of chocolate. One paragraph reads:**
#
# > The people who ate chocolate the most frequently, despite eating more calories and exercising no differently from those who ate the least chocolate, tended to have lower B.M.I.’s. There was a difference of roughly five to seven pounds between subjects who ate five servings of chocolate a week and those who ate none, Dr. Golomb said.
# Dietary studies can be unreliable, since so many complicating factors can influence results, and it is difficult to pinpoint cause and effect. But the researchers adjusted their results for a number of variables, including age, gender, depression, vegetable consumption, as well as fat and calorie intake. “It didn’t matter which of those you added, the relationship remained very stably significant,” said Dr. Golomb.
#
# **Knowing what you do about sources of bias and omitted variable bias, evaluate this paragraph (in the context of the whole article) in a short paragraph.**

# %% [markdown]
# Your answer here

# %% [markdown]
# # PART III: SELF-ASSESSMENT
#
# We have covered a large number of concepts in the course thus far. These concepts serve as the foundation of all the remaining content in the course, making it especially important that you absorb and internalize them before proceeding. To that end, we ask that you take a ten question Canvas quiz linked below. **The results of this quiz will have no bearing on your grade**; it is meant entirely to help you assess your understanding of the nuances of this content before proceeding.
#
# Some notes on the quiz:
#
# * The quiz has a **30 minute timer**; this roughly corresponds to the amount of time it should take you to answer these questions to the best of your ability.
# * In order to make sure that equations render correctly, we suggest taking this quiz using **Firefox or Chrome** and without content blockers.
# * The majority of these questions are multiple choice or select all that apply, and will be graded automatically. The remaining short answer questions will be graded by you after reviewing the solutions.
#
# __The quiz is available at the following links:__
#
# * [Section A (Prof. Carlana)](https://canvas.harvard.edu/courses/118065/assignments/676030)
# * [Section B (Prof. Svoronos)](https://canvas.harvard.edu/courses/118066/assignments/676031)
# * [Section C (Prof. Schneer)](https://canvas.harvard.edu/courses/118067/assignments/676032)
#
# Once you have taken it, please review the solutions that appear and answer the following question:

# %% [markdown]
# **For the three short answer questions (4, 6, and 8), assess the quality of *one* your responses and indicate any corrections you would make to your phrasing. Explain why any corrections you make are necessary. If you feel that you do not need to make any adjustments to your phrasing, provide a version of one response that is geared toward a policymaker who is curious but not well-versed in statistics.**
#
# Feel free to post any questions related to phrasing in [#askforhelp](https://api-202m-b-s123-mrr.slack.com/archives/C04JVR534QK)!

# %% [markdown]
# Which question # did you choose? Select one:
# - [ ] Q4
# - [ ] Q6
# - [ ] Q8
#
# Your tweaked answer here

# %% [markdown]
# # PART IV: PCE ON INTERACTIONS
#
# The goal of this problem set question is to help prepare you for the class on Distributions that will be held on Thursday (the day after this problem set is due), so we can use our time in the classroom most productively. We estimate that the time to engage with this online module is about 30-45 minutes.
#
# Throughout the module you will be asked some questions. We will look at the overall performance of the class to target the class better to your learning needs, but your individual performance on these questions will not count towards your grade. You will get full credit for answering the questions, independently of whether your answers are correct.
#
# **Important Note: This is a full online module with videos and practice problems, not just a quiz.  Your “To Do” list in Canvas will send you directly to the quiz without showing you the module, so please use the links below to access the module instead.**
#
# Remember that you get full credit for completing the required parts of the PCE - your responses will be registered in the system but will not count towards your grade in any way.
#
# __The module is available at the following sites:__
#
# * [Section A (Prof. Carlana)](https://canvas.harvard.edu/courses/118065/modules/253370)
# * [Section B (Prof. Svoronos)](https://canvas.harvard.edu/courses/118066/modules/253371)
# * [Section C (Prof. Schneer)](https://canvas.harvard.edu/courses/118067/modules/253367)

# %% [markdown]
# **Completed the module**
# - [ ] Yes
# - [ ] No
